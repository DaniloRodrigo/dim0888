# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
img = cv2.imread('images/google.jpg', 0)
# plt.hist(img.ravel(),256,[0,256], color='blue'); plt.show()
eq = img
cv2.equalizeHist(img, eq)
plt.hist(img.ravel(),256,[0,256]); plt.show()
# cv2.imshow('dsada', img)
# cv2.waitKey(0);
# Out:
# <img src="data:image/png;base64,..." width="640">
